# %% [markdown]
# Exercise 3
#
# Fermat’s Last Theorem says that there are no positive integers a, b, and c such that
# an + bn = cn
#
# for any values of n greater than 2.
#
#     Write a function named check_fermat that takes four parameters—a, b, c and n—and that checks to see if Fermat’s theorem holds. If n is greater than 2 and it turns out to be true that
#     an + bn = cn
#
#     the program should print, “Holy smokes, Fermat was wrong!” Otherwise the program should print, “No, that doesn’t work.”
#     Write a function that prompts the user to input values for a, b, c and n, converts them to integers, and uses check_fermat to check whether they violate Fermat’s theorem.

# %%
def check_fermat(a,b,c,n):
    if c**n == a**n + b**n:
        if n >= 2:
            print("Holy smokes, Fermat was wrong")
        else:
            print("Fermat's Theorem holds")
    else:
        print("No, that doesn't work")

# %%
check_fermat(1,1,1,1)
# Out:
# No, that doesn't work

# %%
check_fermat(1,1,2,1)
# Out:
# Fermat's Theorem holds

# %%
def get_fermat_vals():
    prompt = 'What is your a value?\n'
    a=int(raw_input(prompt))
    prompt = 'What is your b value?\n'
    b=int(raw_input(prompt))
    prompt = 'What is your c value?\n'
    c=int(raw_input(prompt))
    prompt = 'What is your n value?\n'
    n=int(raw_input(prompt))
    check_fermat(a,b,c,n)

# %%
get_fermat_vals()
# Out:
# What is your a value?
# 1
# What is your b value?
# 3
# What is your c value?
# 4
# What is your n value?
# 1
# Fermat's Theorem holds

# %% [markdown]
# Exercise 5
#
# Read the following function and see if you can figure out what it does. Then run it (see the examples in Chapter 4).
#
# def draw(t, length, n):
#     if n == 0:
#         return
#     angle = 50
#     fd(t, length*n)
#     lt(t, angle)
#     draw(t, length, n-1)
#     rt(t, 2*angle)
#     draw(t, length, n-1)
#     lt(t, angle)
#     bk(t, length*n)

# %% [markdown]
# I have no clue what this program will do.

# %%
import swampy
from swampy.TurtleWorld import *
world=TurtleWorld()
bob=Turtle()

# %%
def draw(t, length, n):
    if n == 0:
        return
    angle = 50
    fd(t, length*n)
    lt(t, angle)
    draw(t, length, n-1)
    rt(t, 2*angle)
    draw(t, length, n-1)
    lt(t, angle)
    bk(t, length*n)
    wait_for_user()

# %%
draw(bob,5,6)

# %% [markdown]
# This program seems to do nothing. I am sick of this TurtleWorld crap.

# %%
world=TurtleWorld()
bob=Turtle()

# %%
def koch(t,x):
    z=x/3.
    koch(t,z)
    lt(t,60)
    koch(t,z)
    rt(t,120)
    koch(t,z)
    lt(t,60)
    koch(t,z)
    wait_for_user()

# %%
koch(bob,3)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-27-3a278066ded9> in <module>()
# ----> 1 koch(bob,3)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# ...
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# <ipython-input-26-e7bec6a411e9> in koch(t, x)
#       1 def koch(t,x):
#       2     z=x/3.
# ----> 3     koch(t,z)
#       4     lt(t,60)
#       5     koch(t,z)
#
# RuntimeError: maximum recursion depth exceeded
